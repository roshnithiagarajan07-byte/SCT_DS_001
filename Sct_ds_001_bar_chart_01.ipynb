# %% [markdown]
# <a href="https://colab.research.google.com/github/roshnithiagarajan07-byte/SCT_DS_001/blob/main/Sct_ds_001_bar_chart_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Sample age group data
age_groups = ['0-20', '21-40', '41-60', '61+']
population = [512, 807, 399, 86]  # in millions (sample data)

plt.figure()
plt.bar(age_groups, population)
plt.xlabel('Age Groups')
plt.ylabel('Population (in millions)')
plt.title('Population Distribution by Age Group')

plt.show()
