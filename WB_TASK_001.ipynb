# %% [markdown]
# <a href="https://colab.research.google.com/github/roshnithiagarajan07-byte/SCT_DS_001/blob/main/WB_TASK_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

HTML("""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Responsive Landing Page</title>

    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
            font-family: Arial, sans-serif;
        }

        body {
            background-color: #0f172a;
            color: white;
        }

        header {
            position: fixed;
            top: 0;
            width: 100%;
            background: transparent;
            padding: 15px 40px;
            transition: 0.3s;
            z-index: 1000;
        }

        header.scrolled {
            background: #020617;
            box-shadow: 0 4px 10px rgba(0,0,0,0.4);
        }

        nav {
            display: flex;
            justify-content: space-between;
            align-items: center;
        }

        nav h2 {
            color: #38bdf8;
        }

        nav ul {
            list-style: none;
            display: flex;
        }

        nav ul li {
            margin-left: 25px;
        }

        nav ul li a {
            text-decoration: none;
            color: white;
            font-weight: bold;
            padding: 5px 10px;
            transition: 0.3s;
        }

        nav ul li a:hover {
            background-color: #38bdf8;
            color: black;
            border-radius: 5px;
        }

        .hero {
            height: 100vh;
            display: flex;
            align-items: center;
            justify-content: center;
            text-align: center;
            padding: 20px;
        }

        .hero h1 {
            font-size: 3rem;
            margin-bottom: 15px;
        }

        .hero p {
            font-size: 1.2rem;
            max-width: 600px;
            margin: auto;
            color: #cbd5f5;
        }

        .section {
            padding: 100px 40px;
            background-color: #020617;
        }

        .section h2 {
            text-align: center;
            margin-bottom: 20px;
            color: #38bdf8;
        }

        .section p {
            text-align: center;
            max-width: 700px;
            margin: auto;
            color: #cbd5f5;
        }

        @media (max-width: 768px) {
            nav ul {
                display: none;
            }

            .hero h1 {
                font-size: 2.2rem;
            }
        }
    </style>
</head>

<body>

<header id="navbar">
    <nav>
        <h2>SkillCraft</h2>
        <ul>
            <li><a href="#">Home</a></li>
            <li><a href="#">About</a></li>
            <li><a href="#">Services</a></li>
            <li><a href="#">Contact</a></li>
        </ul>
    </nav>
</header>

<section class="hero">
    <div>
        <h1>Responsive Landing Page</h1>
        <p>Create an interactive navigation menu that changes color on scroll and hover.</p>
    </div>
</section>

<section class="section">
    <h2>About This Task</h2>
    <p>
        This landing page demonstrates a fixed navigation bar with hover and scroll
        effects using HTML, CSS, and JavaScript.
    </p>
</section>

<script>
    const navbar = document.getElementById("navbar");

    window.addEventListener("scroll", () => {
        if (window.scrollY > 50) {
            navbar.classList.add("scrolled");
        } else {
            navbar.classList.remove("scrolled");
        }
    });
</script>

</body>
</html>
""")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Responsive Landing Page</title>
#
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#             font-family: Arial, sans-serif;
#         }
#
#         body {
#             background-color: #0f172a;
#             color: white;
#         }
#
#         header {
#             position: fixed;
#             top: 0;
#             width: 100%;
#             background: transparent;
#             padding: 15px 40px;
#             transition: 0.3s;
#             z-index: 1000;
#         }
#
#         header.scrolled {
#             background: #020617;
#             box-shadow: 0 4px 10px rgba(0,0,0,0.4);
#         }
#
#         nav {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#         }
#
# ...
